# %%
import pandas as pd

ticket_file = "https://raw.githubusercontent.com/200ritik/TECHNICAL-AI-ASSESSMENT/6202be2324ecfd73a1d2d529bc54ee15fd2bf190/data/support_tickets.csv"

df = pd.read_csv(ticket_file)

print(df.shape)
df.head()
# Out:
# (500, 10)
#   ticket_id        created_at category priority    status  response_time_hrs  \
# 0   TKT-001  2024-02-05 11:14  General      Low  Resolved                3.7
# 1   TKT-002  2024-03-05 17:01  Billing      Low  Resolved                1.2
# 2   TKT-003  2024-02-13 12:09  Billing     High  Resolved                4.8
# 3   TKT-004  2024-03-09 09:59  Billing     High  Resolved                0.6
# 4   TKT-005  2024-03-25 11:49  General      Low      Open                4.9
#
#    resolution_time_hrs agent_id  customer_rating  \
# 0                  7.8   AGT-03              4.0
# 1                 13.7   AGT-09              4.0
# 2                  2.1   AGT-04              5.0
# 3                 10.7   AGT-07              4.0
# 4                  NaN   AGT-05              NaN
#
#                               issue_summary
# 0         Request for product documentation
# 1               Incorrect charge on invoice
# 2                 Unexpected fee on account
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ticket_id            500 non-null    object
#  1   created_at           500 non-null    object
#  2   category             500 non-null    object
#  3   priority             500 non-null    object
#  4   status               500 non-null    object
#  5   response_time_hrs    500 non-null    float64
#  6   resolution_time_hrs  327 non-null    float64
#  7   agent_id             500 non-null    object
#  8   customer_rating      327 non-null    float64
#  9   issue_summary        500 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 39.2+ KB

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Shape: (500, 10)
#
# Columns:
# ['ticket_id', 'created_at', 'category', 'priority', 'status', 'response_time_hrs', 'resolution_time_hrs', 'agent_id', 'customer_rating', 'issue_summary']
#
# Data types:
# ticket_id               object
# created_at              object
# category                object
# priority                object
# status                  object
# response_time_hrs      float64
# resolution_time_hrs    float64
# agent_id                object
# customer_rating        float64
# issue_summary           object
# dtype: object
#
# Missing values:
# ticket_id                0
# created_at               0
# category                 0
# priority                 0
# status                   0
# response_time_hrs        0
# resolution_time_hrs    173
# agent_id                 0
# customer_rating        173
# issue_summary            0
# dtype: int64
#
# Duplicate rows: 0

# %%
print("Status:")
print(df["status"].value_counts())

print("\nPriority:")
print(df["priority"].value_counts())
# Out:
# Status:
# status
# Resolved     327
# Open         111
# Escalated     62
# Name: count, dtype: int64
#
# Priority:
# priority
# Medium      169
# Low         142
# High        134
# Critical     55
# Name: count, dtype: int64

# %%
# negative resolution time
(df["resolution_time_hrs"] < 0).sum()
# Out:
# np.int64(0)

# %%
df["customer_rating"].dropna().between(1, 5).all()
# Out:
# np.True_

# %%
df["customer_rating"].describe()
# Out:
# count    327.000000
# mean       3.749235
# std        1.109686
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: customer_rating, dtype: float64

# %%
# query function checking
df.groupby('status')['ticket_id'].count()
df.groupby('priority')['ticket_id'].count()
df.groupby('category')['ticket_id'].count()
# Out:
# category
# Billing      159
# General      189
# Technical    152
# Name: ticket_id, dtype: int64

# %%
df.groupby('priority')['ticket_id'].count()
# Out:
# priority
# Critical     55
# High        134
# Low         142
# Medium      169
# Name: ticket_id, dtype: int64

# %%
df.groupby('category')['ticket_id'].count()
# Out:
# category
# Billing      159
# General      189
# Technical    152
# Name: ticket_id, dtype: int64

# %%
df["agent_id"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 500 entries, 0 to 499
# Series name: agent_id
# Non-Null Count  Dtype
# --------------  -----
# 500 non-null    object
# dtypes: object(1)
# memory usage: 4.0+ KB

# %%
print(df["agent_id"].value_counts())
# Out:
# agent_id
# AGT-09    50
# AGT-12    49
# AGT-11    47
# AGT-07    47
# AGT-06    46
# AGT-01    46
# AGT-08    42
# AGT-02    40
# AGT-04    37
# AGT-10    35
# AGT-03    34
# AGT-05    27
# Name: count, dtype: int64
